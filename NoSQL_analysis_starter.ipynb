# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
food_db = mongo['uk_food']

# %%
# review the collections in our database
print(food_db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = food_db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query_1 = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query_1)
print(f"There are {count} establishments with a hygiene score of 20.")

# Display the first document in the results using pprint
pprint(establishments.find_one(query_1))
# Out:
# There are 41 establishments with a hygiene score of 20.
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6460d9bac32bed93a3e289ab'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find(query))
# Display the number of rows in the DataFrame
print(f"There are {len(df)} rows in this DataFrame.")
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# There are 41 rows in this DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  6460d9bac32bed93a3e289ab   110681                  0
# 1  6460d9bac32bed93a3e28d2f   612039                  0
# 2  6460d9bac32bed93a3e2903a   730933                  0
# 3  6460d9bac32bed93a3e29234   172735                  0
# 4  6460d9bac32bed93a3e29235   172953                  0
# 5  6460d9bac32bed93a3e29bd6   512854                  0
# 6  6460d9bac32bed93a3e29df6  1537089                  0
# 7  6460d9bac32bed93a3e2b31f   155648                  0
# 8  6460d9bac32bed93a3e2b765  1012883                  0
# 9  6460d9bac32bed93a3e2bf76   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_2 = {'LocalAuthorityName':{'$regex':'London'},'RatingValue': {'$gte': 4}}
show_2 = {'BusinessName': 1, 'LocalAuthorityName': 1, 'RatingValue': 1}
result = establishments.find(query_2, show_2)

# Use count_documents to display the number of documents in the result

count_2 = establishments.count_documents(query_2)
print("Number of documents are: " + str(count_2))


# Display the first document in the results using pprint
pprint(result[0])
# Out:
# Number of documents are: 33
# {'BusinessName': "Charlie's",
#  'LocalAuthorityName': 'City of London Corporation',
#  'RatingValue': 4,
#  '_id': ObjectId('6460d9bac32bed93a3e2a3c8')}

# %%
# Convert the result to a Pandas DataFrame
df_2 = pd.DataFrame(establishments.find(query_2))
# Display the number of rows in the DataFrame
print(f"There are {len(df_2)} rows in this DataFrame.")
# Display the first 10 rows of the DataFrame
df_2.head(10)
# Out:
# There are 33 rows in this DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  6460d9bac32bed93a3e2a3c8   621707                  0
# 1  6460d9bac32bed93a3e2a6f5  1130836                  0
# 2  6460d9bac32bed93a3e2b23d   293783                  0
# 3  6460d9bac32bed93a3e2c03a  1315095                  0
# 4  6460d9bac32bed93a3e2c03c   294474                  0
# 5  6460d9bac32bed93a3e2c746   294900                  0
# 6  6460d9bac32bed93a3e2e854   293756                  0
# 7  6460d9bac32bed93a3e2ec19   878523                  0
# 8  6460d9bac32bed93a3e2ec35   294606                  0
# 9  6460d9bac32bed93a3e2ec36   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Find coordinate information for search
pprint(establishments.find_one({'BusinessName': 'Penang Flavours'},
                               {'geocode.latitude', 'geocode.longitude'}))
# Out:
# {'_id': ObjectId('6460da959627391ed673f02f'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query_3 = {'RatingValue': 5,
         'geocode.latitude': {'$gte': (latitude - degree_search)},
         'geocode.latitude': {'$lte': (latitude + degree_search)},
         'geocode.longitude': {'$gte': (longitude - degree_search)},
         'geocode.longitude': {'$lte': (longitude + degree_search)},
         'scores.Hygiene': {'$ne': None}
         }

show_3 = {'BusinessName': 1,'RatingValue': 1, 'scores.Hygiene':1, 'geocode.latitude': 1, 'geocode.longitude': 1}
result_3 = establishments.find(query_3, show_3).sort('scores.Hygiene', 1).limit(5)

# Print the results
BusinessName_list =[]
RatingValue_list = []
latitude_list = []
longitude_list = []
Hygiene_list = []

for document in result_3:
    pprint(document)
    BusinessName = document['BusinessName']
    Rating = document['RatingValue']
    latitude = document['geocode']['latitude']
    longitude = document['geocode']['longitude']
    Hygiene = document['scores']['Hygiene']
    BusinessName_list.append(BusinessName)
    RatingValue_list.append(Rating)
    latitude_list.append(latitude)
    longitude_list.append(longitude)
    Hygiene_list.append(Hygiene)
# Out:
# {'BusinessName': 'Clifden House Dementia Care Centre',
#  'RatingValue': 5,
#  '_id': ObjectId('6460d9bac32bed93a3e293da'),
#  'geocode': {'latitude': 50.776112, 'longitude': 0.089886},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Beachlands Care Home',
#  'RatingValue': 5,
#  '_id': ObjectId('6460d9bac32bed93a3e293e1'),
#  'geocode': {'latitude': 50.775392, 'longitude': 0.088903},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Ab Fab Rooms',
#  'RatingValue': 5,
#  '_id': ObjectId('6460d9bac32bed93a3e29465'),
#  'geocode': {'latitude': 50.780751, 'longitude': 0.083468},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Angies Newsagents',
#  'RatingValue': 5,
#  '_id': ObjectId('6460d9bac32bed93a3e29388'),
#  'geocode': {'latitude': 50.77601, 'longitude': 0.093059},
#  'scores': {'Hygiene': 0}}
# {'BusinessName': 'Costcutter Claremont',
#  'RatingValue': 5,
#  '_id': ObjectId('6460d9bac32bed93a3e2938a'),
#  'geocode': {'latitude': 50.77601, 'longitude': 0.093059},
# ...

# %%
# Convert result to Pandas DataFrame
top5_df = pd.DataFrame({'BusinessName': BusinessName_list,
                          'RatingValue': RatingValue_list,
                          'latitude': latitude_list,
                          'longitude': longitude_list,
                          'Hygiene': Hygiene_list })

top5_df.head()
# Out:
#                          BusinessName  RatingValue   latitude  longitude  \
# 0  Clifden House Dementia Care Centre            5  50.776112   0.089886
# 1                Beachlands Care Home            5  50.775392   0.088903
# 2                        Ab Fab Rooms            5  50.780751   0.083468
# 3                   Angies Newsagents            5  50.776010   0.093059
# 4                Costcutter Claremont            5  50.776010   0.093059
#
#    Hygiene
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
pipeline = [{'$match': {'LocalAuthorityName': {'$ne': None},'scores.Hygiene': 0}},
            {'$group': {'_id': '$LocalAuthorityName','count': {'$sum': 1}}},
            {'$sort': {'count': -1}},
            {'$limit': 10}]
result = establishments.aggregate(pipeline)
result

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

pipeline = [{'$match': {'LocalAuthorityName': {'$ne': None},'scores.Hygiene': 0}},
            {'$group': {'_id': '$LocalAuthorityName','count': {'$sum': 1}}},
            {'$sort': {'count': -1}},
            {'$limit': 10}]

result = establishments.aggregate(pipeline)


LAN_list = []
count_list =[]

for document in result:
    print(document)
    name = document['_id']
    LAN_list.append(name)
    number = document['count']
    count_list.append(number)
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
lowest_hygiene_df = pd.DataFrame({"LocalAuthorityName": LAN_list,"count":count_list})
# Display the number of rows in the DataFrame
count_rows = len(lowest_hygiene_df["LocalAuthorityName"])
print("Number of rows are: " + str(count_rows))
# Display the first 10 rows of the DataFrame
lowest_hygiene_df.head
# Out:
# Number of rows are: 10
# <bound method NDFrame.head of   LocalAuthorityName  count
# 0             Thanet   1130
# 1          Greenwich    882
# 2          Maidstone    713
# 3             Newham    711
# 4              Swale    686
# 5         Chelmsford    680
# 6             Medway    672
# 7             Bexley    607
# 8    Southend-On-Sea    586
# 9           Tendring    542>
